# %%
def plot_graph(data,v):
    x = [i for i in range(1,len(data))]
    y = [data[i][1] for i in range(1,len(data))]
    y = list(map(float, y))
    plt.plot(x,y,label=v)
    plt.xlabel('Episodes') # naming the x axis      
    plt.ylabel('Rewards') # naming the y axis
    plt.title('Episode vs Reward')

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np

# f_list = []
# f_list.append('fed_pytorch_1client_re.csv')
# f_list.append('fed_pytorch_AvgWeight_fedafter4.csv')
# f_list.append('fed_pytorch_bestscore_fedafter4rounds.csv')
f1 = 'fed_pytorch_1client_re.csv'
f2 = 'fed_pytorch_concurrentRL_after4epsiodes.csv'
f3 = 'fed_pytorch_AvgWeight_fedafter4.csv'
#f4 = 'fed_pytorch_bestscore_fedafter4rounds.csv'
f5 = 'fed_pytorch_gradAvg_fedafter4rounds.csv'

with open(f1, newline='') as f:
    reader = csv.reader(f)
    data = list(reader)
    plot_graph(data,'single_client')
with open(f2,newline='') as f:
    reader = csv.reader(f)
    data = list(reader)
    plot_graph(data,'concurrent_RL')
with open(f3,newline='') as f:
    reader = csv.reader(f)
    data = list(reader)
    plot_graph(data,'FedRL_with_avgWeight')
    print(data[1000:1010])
with open(f4,newline='') as f:
    reader = csv.reader(f)
    data = list(reader)
    #plot_graph(data,'FedRL_with_bestscore')
with open(f4,newline='') as f:
    reader = csv.reader(f)
    data = list(reader)
    plot_graph(data,'FedRL_with_avgGrad')
    print(data[1000:1010])
    
plt.legend(loc='best')    
plt.show()
# Out:
# [['999', '240.20427222465784'], ['1000', '240.48093469624112'], ['1001', '240.0486831764976'], ['1002', '240.34103919930791'], ['1003', '241.08869161341715'], ['1004', '238.20975485506293'], ['1005', '237.76753080644133'], ['1006', '237.5609538191724'], ['1007', '238.01703320486013'], ['1008', '237.9853190497546']]
# [['999', '240.20427222465784'], ['1000', '240.48093469624112'], ['1001', '240.0486831764976'], ['1002', '240.34103919930791'], ['1003', '241.08869161341715'], ['1004', '238.20975485506293'], ['1005', '237.76753080644133'], ['1006', '237.5609538191724'], ['1007', '238.01703320486013'], ['1008', '237.9853190497546']]
