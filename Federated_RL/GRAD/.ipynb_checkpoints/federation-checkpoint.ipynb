# %%
import gym

import numpy as np
import random
from collections import namedtuple, deque
import pandas as pd
import matplotlib.pyplot as plt

from Agent import Agent

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
sum_gradients = {}
def reset_avg_gradients():
    for name, param in agent.local_model.to(device).named_parameters():
        sum_gradients[name] = torch.zeros(size=param.size()).to(device)

# %%
sum_weights = {}
def reset_avg_weights():
    for name, param in agent.local_model.to(device).named_parameters():
        sum_weights[name] = torch.zeros(size=param.size()).to(device)

# %%
def calc_avg_gradients(client):
    for i in range(len(client)):
        gradients = {}
        for name, param in client[i].local_model.to(device).named_parameters():
            gradients[name] = param.grad
            sum_gradients[name] += (gradients[name] / no_of_clients)

# %%
def cal_avg_weights(client):
    for i in range(len(client)):
        weights = {}
        #print(client[i].local_model.fc1.weight)
        for name, param in client[i].local_model.to(device).named_parameters():
            weights[name] = param
            sum_weights[name] += (weights[name] / no_of_clients)

# %%
def cal_best_gradients(client):
    idx = np.argmax([np.mean(client[i].scores_window) for i in range(len(client))])
    #print([np.mean(client[i].scores_window) for i in range(len(client))])
    #print("idx = ",idx)
    for name, param in client[idx].local_model.to(device).named_parameters():
        sum_gradients[name] = param.grad

# %%
def set_new_gradients(sum_gradients,agent):
    for name, param in agent.local_model.to(device).named_parameters():
        param.grad = sum_gradients[name]

# %%
def set_new_weights(sum_weights,agent):
    for name, param in agent.local_model.to(device).named_parameters():
        param = sum_weights[name]

# %%
def get_gradients(agent):
    gradients = {}
    for name, param in agent.local_model.to(device).named_parameters():
        gradients[name] = param.grad

# %%
environment = 'LunarLander-v2'
env = gym.make(environment)
env.seed(0)
state_size = env.observation_space.shape[0]
action_size = env.action_space.n
print('State shape: ', state_size)
print('Number of actions: ', action_size)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
no_of_clients = 5
clients = []
fed_rounds = 350
episode_per_fed = 4
grad_update_method = 'weight_avg' #simple_avg, best_score, weight_avg
max_steps=1000          #max number of steps in an episode
       

for i in range(no_of_clients):
    agent = Agent(state_size=state_size, action_size=action_size, seed=i)
    clients.append(agent)
    
for i in range(no_of_clients):
    print(clients[i])
# Out:
# State shape:  8
# Number of actions:  4
# <Agent.Agent object at 0x0000016AC845CF98>
# <Agent.Agent object at 0x0000016AC846E320>
# <Agent.Agent object at 0x0000016AC846E7F0>
# <Agent.Agent object at 0x0000016AC846EEF0>
# <Agent.Agent object at 0x0000016AC84B5668>

# %%
def dqn(agent,clientID,fed_round):
      # last 100 scores
    #self.eps = self.eps_start                    # initialize epsilon
    for i_episode in range(1, episode_per_fed+1):
        state = env.reset()
        score = 0
        for t in range(max_steps):
            action = agent.act(state, agent.eps)
            next_state, reward, done, _ = env.step(action)
            agent.step(state, action, reward, next_state, done)
            state = next_state
            score += reward
            if done:
                break 
        agent.scores_window.append(score)       # save most recent score
        agent.scores.append(score)              # save most recent score
        agent.eps = max(agent.eps_end, agent.eps_decay*agent.eps) # decrease epsilon
        print('\rfed round {} client {} Episode {}\tAverage Score: {:.2f}'.format(fed_round,clientID,i_episode, np.mean(agent.scores_window)), end="")
        if (episode_per_fed*fed_round + i_episode) % 100 == 0:
            print('\rfed round {} client {} Episode {}\tAverage Score: {:.2f}'.format(fed_round,clientID,i_episode, np.mean(agent.scores_window)))
    agent.eps = agent.eps*0.94

# %%
for f in range(fed_rounds):
    if grad_update_method == 'simple_avg' or grad_update_method == 'best_score':
        reset_avg_gradients()
    elif grad_update_method == 'weight_avg':
        reset_avg_weights()
    else:
        x = 10 #do nothing as of now

    for i in range(no_of_clients):
        dqn(clients[i],i,f)
    
    if grad_update_method == 'simple_avg': 
        calc_avg_gradients(clients)
    elif grad_update_method == 'best_score':
        cal_best_gradients(clients)
    elif grad_update_method == 'weight_avg':
        cal_avg_weights(clients)
    else:
        x = 10 #do nothing as of now
    for i in range(no_of_clients):
        if grad_update_method == 'simple_avg' or grad_update_method == 'best_score':
            set_new_gradients(sum_gradients,clients[i])
        elif grad_update_method == 'weight_avg':
            set_new_weights(sum_weights,clients[i])
        else:
            x = 10 #do nothing as of now
# Out:
# fed round 24 client 0 Episode 4	Average Score: -175.27
# fed round 24 client 1 Episode 4	Average Score: -183.07
# fed round 24 client 2 Episode 4	Average Score: -174.91
# fed round 24 client 3 Episode 4	Average Score: -159.79
# fed round 24 client 4 Episode 4	Average Score: -141.46
# fed round 49 client 0 Episode 4	Average Score: -82.182
# fed round 49 client 1 Episode 4	Average Score: -121.92
# fed round 49 client 2 Episode 4	Average Score: -95.75
# fed round 49 client 3 Episode 4	Average Score: -97.812
# fed round 49 client 4 Episode 4	Average Score: -98.577
# fed round 74 client 0 Episode 4	Average Score: 11.7898
# fed round 74 client 1 Episode 4	Average Score: -25.12
# fed round 74 client 2 Episode 4	Average Score: -69.39
# fed round 74 client 3 Episode 4	Average Score: -34.98
# fed round 74 client 4 Episode 4	Average Score: 1.832
# fed round 99 client 0 Episode 4	Average Score: 59.473
# fed round 99 client 1 Episode 4	Average Score: -12.17
# fed round 99 client 2 Episode 4	Average Score: 30.43
# fed round 99 client 3 Episode 4	Average Score: -32.54
# fed round 99 client 4 Episode 4	Average Score: 200.14
# fed round 124 client 0 Episode 4	Average Score: 96.524
# fed round 124 client 1 Episode 4	Average Score: 112.43
# fed round 124 client 2 Episode 4	Average Score: 119.26
# fed round 124 client 3 Episode 4	Average Score: 7.38
# fed round 124 client 4 Episode 4	Average Score: 186.63
# fed round 149 client 0 Episode 4	Average Score: 150.35
# fed round 149 client 1 Episode 4	Average Score: 159.34
# fed round 149 client 2 Episode 4	Average Score: 207.07
# fed round 149 client 3 Episode 4	Average Score: 76.03
# fed round 149 client 4 Episode 4	Average Score: 182.42
# fed round 174 client 0 Episode 4	Average Score: 158.00
# fed round 174 client 1 Episode 4	Average Score: 123.33
# fed round 174 client 2 Episode 4	Average Score: 179.52
# fed round 174 client 3 Episode 4	Average Score: 147.75
# fed round 174 client 4 Episode 4	Average Score: 196.09
# fed round 199 client 0 Episode 4	Average Score: 202.05
# fed round 199 client 1 Episode 4	Average Score: 182.32
# fed round 199 client 2 Episode 4	Average Score: 201.79
# fed round 199 client 3 Episode 4	Average Score: 187.99
# fed round 199 client 4 Episode 4	Average Score: 229.47
# fed round 224 client 0 Episode 4	Average Score: 221.73
# fed round 224 client 1 Episode 4	Average Score: 244.73
# fed round 224 client 2 Episode 4	Average Score: 229.92
# fed round 224 client 3 Episode 4	Average Score: 203.52
# fed round 224 client 4 Episode 4	Average Score: 221.87
# fed round 249 client 0 Episode 4	Average Score: 242.40
# fed round 249 client 1 Episode 4	Average Score: 246.51
# fed round 249 client 2 Episode 4	Average Score: 201.53
# fed round 249 client 3 Episode 4	Average Score: 217.62
# fed round 249 client 4 Episode 4	Average Score: 239.64
# fed round 274 client 0 Episode 4	Average Score: 245.74
# fed round 274 client 1 Episode 4	Average Score: 249.04
# fed round 274 client 2 Episode 4	Average Score: 213.27
# fed round 274 client 3 Episode 4	Average Score: 218.58
# fed round 274 client 4 Episode 4	Average Score: 240.48
# fed round 299 client 0 Episode 4	Average Score: 226.25
# fed round 299 client 1 Episode 4	Average Score: 251.22
# fed round 299 client 2 Episode 4	Average Score: 234.80
# fed round 299 client 3 Episode 4	Average Score: 251.96
# fed round 299 client 4 Episode 4	Average Score: 209.67
# fed round 324 client 0 Episode 4	Average Score: 237.37
# fed round 324 client 1 Episode 4	Average Score: 249.85
# fed round 324 client 2 Episode 4	Average Score: 244.47
# fed round 324 client 3 Episode 4	Average Score: 256.20
# fed round 324 client 4 Episode 4	Average Score: 215.91
# fed round 349 client 0 Episode 4	Average Score: 244.31
# fed round 349 client 1 Episode 4	Average Score: 247.71
# fed round 349 client 2 Episode 4	Average Score: 252.40
# fed round 349 client 3 Episode 4	Average Score: 233.77
# fed round 349 client 4 Episode 4	Average Score: 191.42

# %%
########################playing the lunar lander######################################
# def final_play():
#     for e in range(4):
#         state = env.reset()
#         done = False
#         while not done:
#             env.render()
#             action = agent.act(state)
#             next_state, reward, done, _ = env.step(action)
#             agent.step(state, action, reward, next_state, done)
#             state = next_state
#final_play()
#env.close()

# %%
def moving_average(vec,window_size):    

    numbers_series = pd.Series(vec)
    windows = numbers_series.rolling(window_size)
    moving_averages = windows.mean()
    moving_averages_list = moving_averages.tolist()
    averaged_v = moving_averages_list[window_size - 1:]
    return(averaged_v)

# %%
def plot_graphs(values1,values2,xstring,ystring,title): 
  
    y1 = values1
    y2 = values2
    x1 = [i for i in range(0,len(values1))]
    x2 = [i for i in range(0,len(values2))]
    plt.plot(x1,y1)
    plt.plot(x2,y2,linewidth = 4)
    plt.xlabel(xstring) # naming the x axis      
    plt.ylabel(ystring) # naming the y axis
    plt.title(title) 

    plt.show()

# %%
window_size = 100
averaged_scr = []
for i in range(no_of_clients):   
    averaged_ = moving_average(clients[i].scores,window_size)
    #averaged_scr.append(averaged_)
    plot_graphs(clients[i].scores,averaged_,'epsiodes','rewards',' rewards vs episodes')
    #print(averaged_[0:20])
    averaged_scr.append(averaged_)
avg_score = averaged_

# %%
df = pd.DataFrame(avg_score)
df.to_csv('trial1.csv')

df2 = pd.DataFrame(averaged_scr)
df2 = df2.transpose()
df2.to_csv('avgGrad_all5clients.csv')
print(df2)
# Out:
#                0           1           2           3           4
# 0    -175.267190 -183.066844 -174.910898 -159.786022 -141.460755
# 1    -174.643925 -181.785561 -175.970439 -161.793497 -142.574746
# 2    -178.069112 -181.903431 -175.052181 -162.316603 -143.246891
# 3    -180.069123 -183.337906 -173.885636 -161.768705 -142.936631
# 4    -176.469574 -183.470284 -172.884922 -161.177968 -146.093521
# ...          ...         ...         ...         ...         ...
# 1296  243.715751  250.037485  255.462146  236.659993  191.931960
# 1297  244.113792  249.865010  255.222105  236.762722  191.799180
# 1298  244.229867  249.934599  255.560961  236.724709  189.161429
# 1299  244.351382  250.294685  251.969699  235.976397  191.538734
# 1300  244.309875  247.714528  252.398332  233.770462  191.417928
#
# [1301 rows x 5 columns]
